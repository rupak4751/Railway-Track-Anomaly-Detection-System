# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.utils import class_weight
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# --- 1. Configuration and Paths ---
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
NUM_CLASSES = 2
EPOCHS = 30
LEARNING_RATE = 0.0001

TRAIN_DIR = "/content/drive/MyDrive/Railway_Fault_Dataset"
TEST_DIR = "/content/drive/MyDrive/Railway_Fault_Dataset_Test"

# --- 2. Data Loading and Augmentation ---
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

class_indices = train_generator.class_indices
print("Class Indices:", class_indices)

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))
print("Calculated Class Weights:", class_weights)

# --- 4. Build the Model (Transfer Learning with ResNet50) ---
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

if NUM_CLASSES == 2:
    predictions = Dense(1, activation='sigmoid')(x)
else:
    predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# --- 5. Compile the Model ---
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy' if NUM_CLASSES == 2 else 'categorical_crossentropy',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall'),
                       tf.keras.metrics.AUC(name='auc')])

model.summary()

# --- 6. Train the Model ---
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator,
    class_weight=class_weights,
    callbacks=[model_checkpoint]  # Removed EarlyStopping
)

# --- 7. Evaluate the Model ---
print("\n--- Evaluating on Test Data ---")
loss, accuracy, precision, recall, auc_score = model.evaluate(test_generator)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test AUC: {auc_score:.4f}")

# --- 8. Classification Report & Confusion Matrix ---
print("\n--- Generating Classification Report ---")
test_labels = test_generator.classes
test_filenames = test_generator.filenames
y_pred_probs = model.predict(test_generator)
y_pred_binary = (y_pred_probs > 0.5).astype(int).flatten()

labels_map = {v: k for k, v in class_indices.items()}
target_names = [labels_map[i] for i in sorted(labels_map.keys())]

cm = confusion_matrix(test_labels, y_pred_binary)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names,
            yticklabels=target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(test_labels, y_pred_binary, target_names=target_names))

fpr, tpr, thresholds = roc_curve(test_labels, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# --- 9. Plot Training History ---
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Found 3982 images belonging to 2 classes.
# Found 322 images belonging to 2 classes.
# Class Indices: {'Defect': 0, 'Non_Defect': 1}
# Calculated Class Weights: {0: np.float64(1.000502512562814), 1: np.float64(0.9994979919678715)}
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_1[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ## Pushing to GitHub
#
# ### Step 1: Initialize Git and Configure User
#
# First, you need to initialize a Git repository in your Colab environment and configure your user name and email. This is usually a one-time setup for the session.

# %%
# %%bash
#
# git init
# git config --global user.email "fahimtahmidrupak@gmail.com" # Replace with your email
# git config --global user.name "Md. fahim tahmid Rupak" # Replace with your name
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %% [markdown]
# ### Step 2: Save the Notebook and Add it to Git
#
# Make sure your notebook is saved (`File > Save` or `Ctrl/Cmd + S`). Then, you can add the notebook file to the Git staging area and commit it.
#
# *Note: Colab notebooks are typically saved as `.ipynb` files. You might need to adjust the filename if it's different.*

# %%
# %%bash
#
# # The previous run successfully identified the notebook file.
# # Let's use the full path to copy it into the Git repository's working directory.
# ORIGINAL_NOTEBOOK_PATH="/content/drive/MyDrive/Colab Notebooks/ track_fault_detection.ipynb"
# NOTEBOOK_BASENAME=$(basename "${ORIGINAL_NOTEBOOK_PATH}")
# TARGET_NOTEBOOK_PATH="/content/${NOTEBOOK_BASENAME}"
#
# # Copy the notebook to the /content/ directory (where the .git repository is initialized)
# cp "${ORIGINAL_NOTEBOOK_PATH}" "${TARGET_NOTEBOOK_PATH}"
# echo "Copied notebook to: ${TARGET_NOTEBOOK_PATH}"
#
# # Now add the copied notebook file to the staging area and commit it
# git add "${TARGET_NOTEBOOK_PATH}"
# git commit -m "Initial commit: Add notebook ${NOTEBOOK_BASENAME}"
# Out:
# Copied notebook to: /content/ track_fault_detection.ipynb
# [main e18b067] Initial commit: Add notebook  track_fault_detection.ipynb
#  1 file changed, 1 insertion(+)
#  create mode 100644  track_fault_detection.ipynb

# %% [markdown]
# ### Step 3: Add Remote Repository and Push
#
# Now, you need to link your local repository to your remote GitHub repository and push your changes. Replace `YOUR_GITHUB_USERNAME` and `YOUR_REPOSITORY_NAME` with your actual GitHub username and the name of your repository. You'll be prompted to enter your GitHub username and Personal Access Token (PAT).
#
# **Important:** For security, use a Personal Access Token (PAT) instead of your password when pushing to GitHub from a command line. You can generate a PAT in your GitHub settings (`Settings > Developer settings > Personal access tokens`).

# %%
# %%bash
#
# git branch -M main # Rename the default branch to 'main' if it's 'master'
# git remote add origin https://github.com/rupak4751/Railway-Track-Anomaly-Detection-System.git # Replace with your repo URL
# git push -u origin main
# Out:
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_5313/1257903681.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', "\ngit branch -M main # Rename the default branch to 'main' if it's 'master'\ngit remote add origin https://github.com/rupak4751/Railway-Track-Anomaly-Detection-System.git # Replace with your repo URL\ngit push -u origin main\n")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# ...

# %% [markdown]
# After executing the last cell, a pop-up window or a prompt in the output will appear asking for your GitHub username and password/PAT. Enter your GitHub username and your Personal Access Token. Your notebook should then be pushed to your GitHub repository!
